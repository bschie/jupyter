# %% [markdown]
# ### Turtle Demo
#
# Demonstration der Turtle-Grafik in jupyter.

# %%
from ipyturtle import Turtle
t = Turtle()
t

#t = Turtle(fixed=False, width=100, height=100)
#t

for seite in range(4):
    t.forward(20)
    t.right(90)
    
t.back(40)
t.forward(10)
t.position()
# Out:
# (-5.3896838775215305e-15, -30.0)
